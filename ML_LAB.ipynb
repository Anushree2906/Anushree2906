# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushree2906/Anushree2906/blob/main/ML_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Anu")
# Out:
# Anu
